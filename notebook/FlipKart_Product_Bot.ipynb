# %%
import pandas as pd
data=pd.read_csv("/content/flipkart_reviews_dataset.csv")
data.head()
# Out:
#          product_id                                      product_title  \
# 0  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 1  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 2  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 3  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 4  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
#
#    rating            summary  \
# 0       5  Terrific purchase
# 1       5  Terrific purchase
# 2       5             Super!
# 3       5             Super!
# 4       5  Terrific purchase
#
#                                               review       location  \
# 0  1-more flexible2-bass is very high3-sound clar...        Shirala
# 1     Super sound and good looking I like that prize  Visakhapatnam
# 2  Very much satisfied with the device at this pr...      Kozhikode
# 3  Nice headphone, bass was very good and sound i...          Jaora
# ...

# %%
# !pip install -q langchain
# !pip install -q langchain-community
# !pip install -q langchain-astradb
# !pip install -q langchain-groq
# !pip install -q pypdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 25.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.7/408.7 kB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 78.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 4.7 MB/s eta 0:00:00

# %%
data.head()
# Out:
#          product_id                                      product_title  \
# 0  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 1  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 2  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 3  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
# 4  ACCFZGAQJGYCYDCM  BoAt Rockerz 235v2 with ASAP charging Version ...
#
#    rating            summary  \
# 0       5  Terrific purchase
# 1       5  Terrific purchase
# 2       5             Super!
# 3       5             Super!
# 4       5  Terrific purchase
#
#                                               review       location  \
# 0  1-more flexible2-bass is very high3-sound clar...        Shirala
# 1     Super sound and good looking I like that prize  Visakhapatnam
# 2  Very much satisfied with the device at this pr...      Kozhikode
# 3  Nice headphone, bass was very good and sound i...          Jaora
# ...

# %%
data.columns
# Out:
# Index(['product_id', 'product_title', 'rating', 'summary', 'review',
#        'location', 'date', 'upvotes', 'downvotes'],
#       dtype='object')

# %%
data=data[['product_title','review']]

# %%
product_list =[]
for index,row in data.iterrows():
  object={
      "product_name":row['product_title'],
      "review":row['review']
  }
  product_list.append(object)

# %%
product_list
# Out:
# [{'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset',
#   'review': "1-more flexible2-bass is very high3-sound clarity is good 4-battery back up to 6 to 8 hour's 5-main thing is fastest charging system is available in that. Only 20 min charge and get long up to 4 hours back up 6-killing look awesome 7-for gaming that product does not support 100% if you want for gaming then I'll recommend you please don't buy but you want for only music then this product is very well for you.. 8-no more wireless headphones are comparing with that headphones at this pric..."},
#  {'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset',
#   'review': 'Super sound and good looking I like that prize'},
#  {'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset',
# ...

# %%
from langchain_core.documents import Document
docs=[]
for object in product_list:
  metadata={"product_name":object['product_name']}
  page_content=object["review"]
  doc=Document(page_content=page_content,metadata=metadata)
  docs.append(doc)

# %%
docs
# Out:
# [Document(metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content="1-more flexible2-bass is very high3-sound clarity is good 4-battery back up to 6 to 8 hour's 5-main thing is fastest charging system is available in that. Only 20 min charge and get long up to 4 hours back up 6-killing look awesome 7-for gaming that product does not support 100% if you want for gaming then I'll recommend you please don't buy but you want for only music then this product is very well for you.. 8-no more wireless headphones are comparing with that headphones at this pric..."),
#  Document(metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content='Super sound and good looking I like that prize'),
# ...

# %%
len(docs)
# Out:
# 9374

# %%
GROQ_API="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"
ASTRA_DB_API_ENDPOINT="https://4b349fc0-d1ec-4b5f-b38c-ec0ccb682784-us-east-2.apps.astra.datastax.com"
ASTRA_DB_APPLICATION_TOKEN="AstraCS:ZINIMuiEvYNPqAcLjPLAOIfT:19781fe90305b8d8ddac1afb98cad3015312380466630cd5a22483f3beeda1a1"
ASTRA_DB_KEYSPACE="default_keyspace"
HF_TOKEN="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"

# %%
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings
embeddings = HuggingFaceInferenceAPIEmbeddings(api_key=HF_TOKEN,model_name="BAAI/bge-base-en-v1.5")

# %%
from langchain_astradb import AstraDBVectorStore
vstore = AstraDBVectorStore(
    embedding=embeddings,
    collection_name="flipkart_bot",
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    token=ASTRA_DB_APPLICATION_TOKEN,
    namespace=ASTRA_DB_KEYSPACE,
)

# %%
# 5000 records
docs=docs[5001:9374]
docs = [[float(x) for x in doc if isinstance(x, (int, float))] for doc in docs]
#convert back to doc
from langchain_core.documents import Document

# Assuming you still have access to the original `product_list` for metadata
reconstructed_docs = []
for i, vector in enumerate(docs):
    # Retrieve metadata from the corresponding original product
    metadata = {"product_name": product_list[i]['product_name']}

    # Convert the vector back to string format for page_content if needed
    page_content = " ".join(map(str, vector))  # or any other format that suits `page_content`

    # Recreate Document
    doc = Document(page_content=page_content, metadata=metadata)
    reconstructed_docs.append(doc)

# Now `reconstructed_docs` holds the Documents in the required format

# %%
insert_ids = vstore.add_documents(reconstructed_docs)

# %%
from langchain_groq import ChatGroq
model = ChatGroq(groq_api_key=GROQ_API,model="llama-3.1-70b-versatile",temperature=0.3)

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import MessagesPlaceholder
from langchain.chains import create_history_aware_retriever

# %%
retriever = vstore.as_retriever(search_kwargs={"k": 5})

# %%
from langchain_core.prompts import ChatPromptTemplate
retriever_prompt ="""
Given a chat history and the latest user question which might reference context in the chat history,
formulate a standalone question which can be understood without the chat history,
Do not answer the question just reformulate it if needed and otherwise return as it is.
"""

# %%
contextualize_q_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", retriever_prompt),
        MessagesPlaceholder(variable_name="chat_history"),
        ("human", "{input}"),
    ]
)

# %%
history_aware_retriever = create_history_aware_retriever(model,retriever,contextualize_q_prompt)

# %%
PRODUCT_BOT_TEMPLATE="""
      You are an Ecommerce bot is an expert in prodcut recommendation and customer queries,
      It analyses product titles and reviews to provide accurate and helpful responses.
      Ensure your answers are relevant to the product context and refrain from straying off-topic.
      Your responses should be concise and informative.

      CONTEXT:
      {context}

      QUESTION: {input}

      YOUR ANSWER:

"""

# %%
qa_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", PRODUCT_BOT_TEMPLATE),
        MessagesPlaceholder(variable_name="chat_history"),
        ("human", "{input}"),
    ]
)

# %%
question_answer_chain = create_stuff_documents_chain(model,qa_prompt)
chain = create_retrieval_chain(history_aware_retriever, question_answer_chain)

# %%
chat_history=[]
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
store = {}

# %%
def get_session_history(session_id)->BaseChatMessageHistory:
  if session_id not in store:
    store[session_id]=ChatMessageHistory()
  return store[session_id]

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="chat_history",
    output_messages_key="answer"
)

# %%
response = chain_with_memory.invoke(
    {"input": "Can you tell me the best Bluetooth buds?"},
    {"configurable": {"session_id": "prav"}}
)

# %%
print(response['context'])
# Out:
# [Document(id='bb6ab7846c5a4354b22d7906241bf7ae', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content=''), Document(id='72bed14a3ad84b76a83456c7135ba0bf', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content=''), Document(id='9e48af6f4e0c4614b7bc7f7156f47763', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content=''), Document(id='5944cbb7584e4ef99916678811ce8a35', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content=''), Document(id='48e61a7a09e04b789fb53154d4481391', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content='')]

# %%
response = chain_with_memory.invoke(
    {"input": "Can you tell best IPhone?"},
    {"configurable": {"session_id": "unique_session_id"}}
)
print(response['context'])
# Out:
# [Document(id='04b5fa647c964f7fb98351a506f9d837', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content=''), Document(id='72bed14a3ad84b76a83456c7135ba0bf', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content=''), Document(id='9e48af6f4e0c4614b7bc7f7156f47763', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content=''), Document(id='5944cbb7584e4ef99916678811ce8a35', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content=''), Document(id='4d44513ac4be4ce2b2591efb7cdd7da3', metadata={'product_name': 'BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset'}, page_content='')]

# %%
store
# Out:
# {'unique_session_id': InMemoryChatMessageHistory(messages=[HumanMessage(content='Can you tell me the best Bluetooth buds?', additional_kwargs={}, response_metadata={}), AIMessage(content='Based on customer reviews and ratings, some of the top-rated Bluetooth earbuds are:\n\n1. Sony WF-1000XM4: Known for their excellent noise-cancellation and sound quality.\n2. Apple AirPods Pro: Popular for their seamless integration with Apple devices and compact design.\n3. Sennheiser Momentum True Wireless 2: Praised for their clear sound and long battery life.\n4. Samsung Galaxy Buds Pro: Offers great sound quality and a compact design with wireless charging.\n5. Beats Powerbeats Pro 2: Favored for their long battery life and sweat-resistant design.\n\nThese are just a few examples, and the best earbuds for you will depend on your specific needs and preferences. Would you like me to recommend based on a specific feature or budget?', additional_kwargs={}, response_metadata={}), HumanMessage(conten
# ...
